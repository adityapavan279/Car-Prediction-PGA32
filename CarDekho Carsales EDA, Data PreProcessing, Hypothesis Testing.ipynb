# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# set up working directory
import io
# %cd "D:\New folder"
# Out:
# D:\New folder

# %%
carsales = pd.read_csv("Car details v3.csv")

# %%
carsales
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
carsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
carsales.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
carsales.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8123       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126         Tata Indigo CR4  2013         290000      25000  Diesel
# 8127         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#       max_power                     torque  seats
# 8123  82.85 bhp           113.7Nm@ 4000rpm    5.0
# ...

# %%
carsales.tail(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 8118                  Hyundai i20 Magna  2013         380000      25000
# 8119        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120            Hyundai Santro Xing GLS  2008         120000     191000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
# 8126                    Tata Indigo CR4  2013         290000      25000
# 8127                    Tata Indigo CR4  2013         290000      25000
#
#         fuel seller_type transmission                 owner     mileage  \
# 8118  Petrol  Individual       Manual           First Owner   18.5 kmpl
# ...

# %%
 # Data Preprocessing
# in this case depenednt variable is selling_price
# Research objective- build a model that predicts price of a car when data is input

# %%
# pandas replace()-- first pattern to be replaced and second what is the replcement
carsales.mileage = carsales.mileage.str.replace(" kmpl","")

# %%
carsales.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner mileage   engine   max_power  \
# 0  Individual       Manual   First Owner    23.4  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner   21.14  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner    17.7  1497 CC      78 bhp
# 3  Individual       Manual   First Owner    23.0  1396 CC      90 bhp
# 4  Individual       Manual   First Owner    16.1  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
carsales.engine = carsales.engine.str.replace("CC","")

# %%
carsales.max_power = carsales.max_power.str.replace(" bhp","")

# %%
carsales.mileage =carsales.mileage.str.replace("km/kg","")

# %%
carsales.mileage = carsales.mileage.astype("float")

# %%
carsales.max_power = carsales.max_power.astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 carsales.max_power = carsales.max_power.astype("float")
#
# File ~\anaconda\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
carsales.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage engine max_power  \
# 0  Individual       Manual   First Owner    23.40  1248         74
# 1  Individual       Manual  Second Owner    21.14  1498     103.52
# 2  Individual       Manual   Third Owner    17.70  1497         78
# 3  Individual       Manual   First Owner    23.00  1396         90
# 4  Individual       Manual   First Owner    16.10  1298       88.2
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
carsales ['companyname'] = carsales.name.str.split().str[0]

# %%
carsales.companyname.value_counts(dropna = False)
# Out:
# companyname
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
carsales['torq'] = carsales.torque.str.extract('(\d+(rpm))')[0]

# %%
carsales.torq = carsales.torq.str.replace('rpm',"")

# %%
carsales.torq.head()
# Out:
# 0    2000
# 1    2500
# 2     NaN
# 3    2750
# 4     NaN
# Name: torq, dtype: object

# %%
carsales
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# ### Missing Values
# #

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
carsales.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats', 'companyname', 'torq'],
#       dtype='object')

# %%
carsales[['mileage','engine', 'max_power', 'seats', "torq"]].describe()
# Out:
#            mileage        seats
# count  7907.000000  7907.000000
# mean     19.418783     5.416719
# std       4.037145     0.959588
# min       0.000000     2.000000
# 25%      16.780000     5.000000
# 50%      19.300000     5.000000
# 75%      22.320000     5.000000
# max      42.000000    14.000000

# %%
carsales.engine = pd.to_numeric(carsales.engine, errors= "coerce")
# brute force conversion - pd.to_numeric
# errors = coerce wherever number is not understood, impute with NA or missing value

# %%
carsales.max_power = pd.to_numeric(carsales.max_power, errors= "coerce")

# %%
carsales.torq = pd.to_numeric(carsales.torq, errors= "coerce")

# %%
carsales[['mileage','engine', 'max_power', 'seats', "torq"]].describe()
# Out:
#            mileage       engine    max_power        seats         torq
# count  7907.000000  7907.000000  7912.000000  7907.000000  7332.000000
# mean     19.418783  1458.625016    91.517919     5.416719  3072.693126
# std       4.037145   503.916303    35.822499     0.959588   919.097085
# min       0.000000   624.000000     0.000000     2.000000   500.000000
# 25%      16.780000  1197.000000    68.050000     5.000000  2250.000000
# 50%      19.300000  1248.000000    82.000000     5.000000  3000.000000
# 75%      22.320000  1582.000000   102.000000     5.000000  4000.000000
# max      42.000000  3604.000000   400.000000    14.000000  5300.000000

# %%
import seaborn as sns

# %%
sns.boxplot(carsales[['mileage','engine', 'max_power', 'seats', "torq"]])
# Out:
# <Axes: >

# %%
# Median Imputation of Missing Values
for col in ['mileage','engine', 'max_power', 'seats', 'torq']:
    carsales[col] = carsales[col].fillna(carsales[col].median())

# %%
carsales[['mileage','engine', 'max_power', 'seats', "torq"]].describe()
# Out:
#            mileage      engine    max_power        seats         torq
# count  8128.000000  8128.00000  8128.000000  8128.000000  8128.000000
# mean     19.415554  1452.89813    91.264982     5.405389  3065.574065
# std       3.981922   498.19672    35.376388     0.948874   873.194266
# min       0.000000   624.00000     0.000000     2.000000   500.000000
# 25%      16.800000  1197.00000    68.100000     5.000000  2500.000000
# 50%      19.300000  1248.00000    82.000000     5.000000  3000.000000
# 75%      22.277500  1582.00000   101.250000     5.000000  4000.000000
# max      42.000000  3604.00000   400.000000    14.000000  5300.000000

# %%
# create new variable age based on the purchase year as of year 2022
carsales['Age'] = 2022-carsales.year

# %%
carsales.Age.describe()
# Out:
# count    8128.000000
# mean        8.195989
# std         4.044249
# min         2.000000
# 25%         5.000000
# 50%         7.000000
# 75%        11.000000
# max        39.000000
# Name: Age, dtype: float64

# %%
carsales.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats', 'companyname', 'torq', 'Age'],
#       dtype='object')

# %%
carsales = carsales.drop(['name', 'year', 'torque'], axis =1)

# %% [markdown]
# ### Data Visualization

# %%
# Frequecny counts and Pie diagram with percentage for variables fuels, seller_type and owner
# Crosstabulation and Stacked Bar plot for variables Fuel and seller_type, owner and fuel, company name and fuel
# Barplot of Companyname
# Histogram, Boxplot and Desnity curve for the variables selling_price, km_driven, mileage

# %%
carsales.fuel.value_counts().plot(kind='pie',autopct ="%.2f%%",
                                 colors = ["red","yellow","green","blue"])
# Out:
# <Axes: ylabel='count'>

# %%
carsales.seller_type.value_counts().plot(kind='pie',autopct ="%.2f%%",
                                 colors = ["red","yellow","green","blue"])
# Out:
# <Axes: ylabel='count'>

# %%
carsales.owner.value_counts().plot(kind='pie',autopct ="%.2f%%",
                                 colors = ["red","yellow","green","blue"])
# Out:
# <Axes: ylabel='count'>

# %%
# Cross Tabulation of seller_type 
ax=pd.crosstab(carsales.seller_type,carsales.fuel).plot(kind="bar",stacked="True")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Cross Tabulation of owner and fuel 
ax=pd.crosstab(carsales.owner,carsales.fuel).plot(kind="bar",stacked="True")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Cross Tabulation of seller_type 
ax=pd.crosstab(carsales.companyname,carsales.fuel).plot(kind="bar",stacked="True",figsize=(15,10))
for i in ax.containers:
    ax.bar_label(i)

# %%
fig,ax=plt.subplots(3,1)
sns.histplot(carsales.selling_price,ax=ax[0])
sns.boxplot(carsales.selling_price,ax=ax[1],orient="h")
sns.kdeplot(carsales.selling_price,ax=ax[2])
# Out:
# <Axes: xlabel='selling_price', ylabel='Density'>

# %%
fig,ax=plt.subplots(3,1)
sns.histplot(carsales.mileage,ax=ax[0])
sns.boxplot(carsales.mileage,ax=ax[1],orient="h")
sns.kdeplot(carsales.mileage,ax=ax[2])
# Out:
# <Axes: xlabel='mileage', ylabel='Density'>

# %%
fig,ax=plt.subplots(3,1)
sns.histplot(carsales.km_driven,ax=ax[0])
sns.boxplot(carsales.km_driven,ax=ax[1],orient="h")
sns.kdeplot(carsales.km_driven,ax=ax[2])
# Out:
# <Axes: xlabel='km_driven', ylabel='Density'>

# %%
carsales
# Out:
#       selling_price  km_driven    fuel seller_type transmission  \
# 0            450000     145500  Diesel  Individual       Manual
# 1            370000     120000  Diesel  Individual       Manual
# 2            158000     140000  Petrol  Individual       Manual
# 3            225000     127000  Diesel  Individual       Manual
# 4            130000     120000  Petrol  Individual       Manual
# ...             ...        ...     ...         ...          ...
# 8123         320000     110000  Petrol  Individual       Manual
# 8124         135000     119000  Diesel  Individual       Manual
# 8125         382000     120000  Diesel  Individual       Manual
# 8126         290000      25000  Diesel  Individual       Manual
# 8127         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats companyname  \
# 0              First Owner    23.40  1248.0      74.00    5.0      Maruti
# ...

# %% [markdown]
# ###  Hypothesis testing

# %% [raw]
# # comparing of means/Averages of 2 or more than 3 levels/groups/classes
# # fundamental assumption - Means?averages  must be different
#
# # variabel 1 Numberical and Variable 2 categorical with exactly 2 levels/gruops/classes- 2 sample Independent Test
#
# # vaiable 1 Numerical and variable 2 categroical with more than 2 levels/groups/classes - Annova Single Factor
#
# # variable 1 categorical and variable 2 categorical - Chi Square Test of Independence
#
# # Variable 1 numeric and before and variable 2 Numeric and after - Paired sammple T Test
#
# # process of conducting hypothesis test
#
# 1) Groupby() - mean and varaince
#
# 2) Frame Null and Alternate Hypothesis
#
# 3) Split Data into as many levels
#
# 4) Conduct test and interpret based on P-value
#
# p- value interpretaation - 2 tail test( rejection both sides)
#
# p-value less than 0.05, Reject Null
#
# p-value greater than 0.05, fail to reject (Accept) Null
#
# 0.005 menas 5% Alpha(probable error rate) and 95% confidence level

# %%
# Test Null Average selling_price of different transmission is equal
# using groupby
np.round(carsales.selling_price.groupby(carsales.transmission).mean(),2)
# since exactly 2 levels/groups/classes - 2sample independent T test
# Out:
# transmission
# Automatic    1870827.60
# Manual        455425.86
# Name: selling_price, dtype: float64

# %%
np.round(carsales.selling_price.groupby(carsales.transmission).var(),2)
# Out:
# transmission
# Automatic    2.691349e+12
# Manual       8.872370e+10
# Name: selling_price, dtype: float64

# %%
# Frame Null and Alternate Hypothesis

# Null- there is no significant difference in averagr selling_price of auto and manual cars
# H0 - mean of auto = mean of manual

# Alternate -there is significant difference in averagr selling_price of auto and manual cars
# Ha - mean of auto != mean of manual

# %%
# Split Data into Auto and Manual
auto = carsales[carsales.transmission == "Automatic"]
manual = carsales[carsales.transmission == "Manual"]

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(auto.selling_price,manual.selling_price,equal_var=False)
# since pvalue=8.531946079710315e-129 is less than 0.05, Reject Null
# Difference in Means is statistically significant
# Out:
# TtestResult(statistic=27.888813193478946, pvalue=8.531946079710315e-129, df=1059.2814874514092)

# %%
# Test Null Average for the Auto and Manual cars equal
# groupby() -- mean and var, frame Null and Alt, conduct Test and interpret

# %%
carsales.km_driven.groupby(carsales.transmission).mean()
# Out:
# transmission
# Automatic    40276.086667
# Manual       74202.188895
# Name: km_driven, dtype: float64

# %%
carsales.km_driven.groupby(carsales.transmission).var()
# Out:
# transmission
# Automatic    1.250228e+09
# Manual       3.338416e+09
# Name: km_driven, dtype: float64

# %%
# Frame Null and Alternate Hypothesis

# Null- there is no significant difference in average km_driven of auto and manual cars

# Alternate -there is significant difference in average km_driven of auto and manual cars

# %%
ttest_ind(auto.km_driven,manual.km_driven,equal_var=False)
# since pvalue=2.851791533885484e-131 is less than 0.05, reject Null
# Out:
# TtestResult(statistic=-26.31311123939943, pvalue=2.851791533885484e-131, df=1998.1925323759576)

# %%
# Test Null mileage of auto and manual cars equal

# %%
carsales.mileage.groupby(carsales.transmission).mean()
# Out:
# transmission
# Automatic    17.579638
# Manual       19.687906
# Name: mileage, dtype: float64

# %%
carsales.mileage.groupby(carsales.transmission).var()
# Out:
# transmission
# Automatic    15.773254
# Manual       15.295890
# Name: mileage, dtype: float64

# %%
# Frame Null and Alternate Hypothesis

# Null- there is no significant difference in average mileage of auto and manual cars

# Alternate -there is significant difference in average mileage of auto and manual cars

# %%
ttest_ind(auto.mileage,manual.mileage,equal_var=False)
# since pvalue=1.924423779471943e-53 is less than 0.05, Reject Null
# Out:
# TtestResult(statistic=-16.08325308774936, pvalue=1.924423779471943e-53, df=1368.3244399399287)

# %%
# Test Null Average selling_price for different fuel is equal
# more than 2 levels/groups/classes  - Annova Single factor

# %%
carsales.selling_price.groupby(carsales.fuel).mean()
# Out:
# fuel
# CNG       301017.491228
# Diesel    791452.921627
# LPG       200421.052632
# Petrol    462441.061691
# Name: selling_price, dtype: float64

# %%
carsales.selling_price.groupby(carsales.fuel).var()
# Out:
# fuel
# CNG       1.245061e+10
# Diesel    8.260897e+11
# LPG       7.211656e+09
# Petrol    3.903611e+11
# Name: selling_price, dtype: float64

# %%
# Frame Null and Alternate Hypothesis

# Null- there is no significant difference in average selling_price of different fuel cars

# Alternate -there is significant difference in average selling_price of different fuel cars

# %%
# Split data
cng = carsales[carsales.fuel=="CNG"]
diesel = carsales[carsales.fuel=="Diesel"]
petrol = carsales[carsales.fuel=="Petrol"]
lpg = carsales[carsales.fuel =="LPG"]

# %%
from scipy.stats import f_oneway

# %%
f_oneway(cng.selling_price,diesel.selling_price,lpg.selling_price,petrol.selling_price)
# since pvalue=7.768067697277526e-78 is less than 0.05, Reject Null
# Out:
# F_onewayResult(statistic=122.88062883888716, pvalue=7.768067697277526e-78)

# %%
# test null average mileage of different fuel cars equal

# %%
carsales.mileage.groupby(carsales.fuel).mean()
# Out:
# fuel
# CNG       23.824211
# Diesel    19.634607
# LPG       18.634211
# Petrol    19.088956
# Name: mileage, dtype: float64

# %%
# Frame Null and Alternate Hypothesis

# Null- there is no significant difference in average selling_price of different fuel cars

# Alternate -there is significant difference in average selling_price of different fuel cars

# %%
f_oneway(cng.mileage,petrol.mileage,lpg.mileage,diesel.mileage)
# since pvalue=1.218592729218157e-23 is less than 0.05, Reject Null
# Out:
# F_onewayResult(statistic=36.842275392000154, pvalue=1.218592729218157e-23)

# %%
# test Null No Association between fuel and seller_type
pd.crosstab(carsales.fuel,carsales.seller_type)
# Out:
# seller_type  Dealer  Individual  Trustmark Dealer
# fuel
# CNG               0          57                 0
# Diesel          704        3664                34
# LPG               2          36                 0
# Petrol          420        3009               202

# %%
# Null - There is no Association between both variables
# Alt -  There is Association between both variables

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(carsales.fuel,carsales.seller_type))
# since pvalue=1.2641980292155646e-40 is less than 0.05, Reject Null
# Out:
# Chi2ContingencyResult(statistic=200.82868982394092, pvalue=1.2641980292155646e-40, dof=6, expected_freq=array([[7.89640748e+00, 4.74485728e+01, 1.65501969e+00],
#        [6.09824311e+02, 3.66436171e+03, 1.27813976e+02],
#        [5.26427165e+00, 3.16323819e+01, 1.10334646e+00],
#        [5.03015010e+02, 3.02255733e+03, 1.05427657e+02]]))

# %%
carsales.columns
# Out:
# Index(['selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'seats', 'companyname',
#        'torq', 'Age'],
#       dtype='object')

# %%
carsales = pd.get_dummies(carsales,columns=['fuel', 'seller_type', 'transmission','owner','seats', 'companyname'])

# %%
pd.set_option("display.max_columns",62)
carsales.head()
# Out:
#    selling_price  km_driven  mileage  engine  max_power    torq  Age  \
# 0         450000     145500    23.40  1248.0      74.00  2000.0    8
# 1         370000     120000    21.14  1498.0     103.52  2500.0    8
# 2         158000     140000    17.70  1497.0      78.00  3000.0   16
# 3         225000     127000    23.00  1396.0      90.00  2750.0   12
# 4         130000     120000    16.10  1298.0      88.20  3000.0   15
#
#    fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Dealer  \
# 0     False         True     False        False               False
# 1     False         True     False        False               False
# 2     False        False     False         True               False
# 3     False         True     False        False               False
# 4     False        False     False         True               False
#
#    seller_type_Individual  seller_type_Trustmark Dealer  \
# 0                    True                         False
# ...

# %%
# The distribution of dependent variable decides whether to use Regression or Classification algorithim

# Regression Algorithim - Dependent Variable(y) is numerical, continuos, closer to normal distribution(bell curve)
# with minimum outliers and no missing values

# %%
# Classification Algorithim- Dependent variable is non numeric either binary(yes/no) ormultinomial more than
#levels/classes/groups

# Multiple Linear Regression(MLR) explains linear releationship between dependent variable(y) and multiple independet vaariables(x's)
# MLR is an equation
# y = B0+B1X1+B2X2+B3X3+...........+BnXn+Et
# y == Dependent variable or prediction variable
# B0 - Intercept or constant(point at which straight lline touched y axis)
# B1,B2,B3,..............Bn - Coefficients
# X1,X2,X3,X4..............Xn - Independent variables or predictors
# Et  - Error Term or residual  = Actualvalue - Predict value


# ASSUMPTIONS - MLR is a parametric algorithm(many assumptions)   PRE MODEL ASSUMPTIONS
# 1) Depedent Variable y must be numerical,continuos,closer to normal distributionwith minimum outliers and no missing values
# 2) Independent variable(X's) can be both numerical and numericalcategorical
# 3) No Multicollinearity - Multicollinearity is very strong correlation (>0.90) among variables. If Multicollinearity is found do not include both 
#    variables and choose one among them, else overfitting will occur.
# 4) Exogentity - Dependent variable is dependent on independent variables but not viceversa.
#   y is dependent on X's  but X's do not depend on y
# 5) Varience Inflation Factor(VIF) - VIF Greater than 5 indicates  multicollinearity
# 6) There must be a logical linear relationship between dependent variable and independent variables

# POST MODEL ASSUMPTIONS
#7) Residuals must be normally distibuted. Check during Q-Q plot.
# 8) residuals must be homoscedasity in nature



# The Interpretation of output (python only)
# R Square must be between 0.60 - 0.95. R Square explains amount of varience occuring in dependent variable caused by independent variables or model
# less than 0.60 - underfitting
# greater than 0.95 - overfitting

# Intercept + Coefficients for creating predictive equation

# Statistical Interpretaion of output
# 1) Adjusted R Square mst be between 0.60 - 0.95. Adj R Square is sensitive to independent variable's siginificance, if independent variable is 
# siginificant it will increase and if variable is insiginificant it will decrease.

# 2) Model P-Values(lies below Adj R Square) or significance F in MS Excel must be less than 0.05
# Null - Coefficients(B's) are equal to Zero.
# Alt - Coefficients(B's) are not equal to zero.

# 3) Independent Variables(X's) p-value must be less than 0.5, Reject Null
# Null - Independent Variable is Insignificant
# Alt - Independent Variable is Significant

# %%
carsales.columns
# Out:
# Index(['selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'torq',
#        'Age', 'fuel_CNG', 'fuel_Diesel', 'fuel_LPG', 'fuel_Petrol',
#        'seller_type_Dealer', 'seller_type_Individual',
#        'seller_type_Trustmark Dealer', 'transmission_Automatic',
#        'transmission_Manual', 'owner_First Owner',
#        'owner_Fourth & Above Owner', 'owner_Second Owner',
#        'owner_Test Drive Car', 'owner_Third Owner', 'seats_2.0', 'seats_4.0',
#        'seats_5.0', 'seats_6.0', 'seats_7.0', 'seats_8.0', 'seats_9.0',
#        'seats_10.0', 'seats_14.0', 'companyname_Ambassador',
#        'companyname_Ashok', 'companyname_Audi', 'companyname_BMW',
#        'companyname_Chevrolet', 'companyname_Daewoo', 'companyname_Datsun',
#        'companyname_Fiat', 'companyname_Force', 'companyname_Ford',
#        'companyname_Honda', 'companyname_Hyundai', 'companyname_Isuzu',
#        'companyname_Jaguar', 'companyname_Jeep', 'companyname_Kia',
# ...

# %%
# check for Multicollinearity
carsales[['selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'torq',
       'Age']].corr()
# No Multicollinearity
# Out:
#                selling_price  km_driven   mileage    engine  max_power  \
# selling_price       1.000000  -0.225534 -0.125040  0.458345   0.747935
# km_driven          -0.225534   1.000000 -0.171746  0.198911  -0.040599
# mileage            -0.125040  -0.171746  1.000000 -0.574128  -0.372897
# engine              0.458345   0.198911 -0.574128  1.000000   0.703612
# max_power           0.747935  -0.040599 -0.372897  0.703612   1.000000
# torq               -0.026574  -0.225604 -0.173322 -0.201131  -0.001697
# Age                -0.414092   0.418006 -0.311657 -0.035851  -0.224704
#
#                    torq       Age
# selling_price -0.026574 -0.414092
# km_driven     -0.225604  0.418006
# mileage       -0.173322 -0.311657
# engine        -0.201131 -0.035851
# max_power     -0.001697 -0.224704
# torq           1.000000 -0.099360
# Age           -0.099360  1.000000

# %%
sns.heatmap(carsales[['selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'torq',
       'Age']].corr(),annot = True,cmap="plasma")
# Out:
# <Axes: >

# %%
# split data into Dependent Variable(y) and independent variable(X)

# %%
y = carsales.selling_price
X = carsales.drop("selling_price",axis=1)

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 8128, dtype: int64

# %%
X
# Out:
#       km_driven  mileage  engine  max_power    torq  Age  fuel_CNG  \
# 0        145500    23.40  1248.0      74.00  2000.0    8     False
# 1        120000    21.14  1498.0     103.52  2500.0    8     False
# 2        140000    17.70  1497.0      78.00  3000.0   16     False
# 3        127000    23.00  1396.0      90.00  2750.0   12     False
# 4        120000    16.10  1298.0      88.20  3000.0   15     False
# ...         ...      ...     ...        ...     ...  ...       ...
# 8123     110000    18.50  1197.0      82.85  4000.0    9     False
# 8124     119000    16.80  1493.0     110.00  3000.0   15     False
# 8125     120000    19.30  1248.0      73.90  2000.0   13     False
# 8126      25000    23.57  1396.0      70.00  3000.0    9     False
# 8127      25000    23.57  1396.0      70.00  3000.0    9     False
#
#       fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Dealer  \
# 0            True     False        False               False
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regmodel=LinearRegression().fit(X,y)

# %%
regmodel.score(X,y)
# Out:
# 0.8551297833952862

# %%
# R Square = 0.8551297833952862
# 85.51% varience in selling_price(y) is explained by this model

# %%
regmodel.intercept_
# Out:
# 1501075.6950207911

# %%
print(list(zip(X.columns,regmodel.coef_)))
# Out:
# [('km_driven', -0.6123706148584247), ('mileage', -284.9796073352735), ('engine', 50.37211758868989), ('max_power', 6748.356477032561), ('torq', -40.06732951720187), ('Age', -44504.59990054098), ('fuel_CNG', -82163.53291893529), ('fuel_Diesel', -1380.7230756882927), ('fuel_LPG', 107495.05474274233), ('fuel_Petrol', -23950.798748098954), ('seller_type_Dealer', 37341.31028643984), ('seller_type_Individual', -21425.74676486758), ('seller_type_Trustmark Dealer', -15915.563521558302), ('transmission_Automatic', 49101.751827885135), ('transmission_Manual', -49101.751827961416), ('owner_First Owner', -470015.6926480193), ('owner_Fourth & Above Owner', -491880.3983136314), ('owner_Second Owner', -526118.4707576067), ('owner_Test Drive Car', 1991199.2893603018), ('owner_Third Owner', -503184.7276410669), ('seats_2.0', -80631.97805530073), ('seats_4.0', 293416.6437911836), ('seats_5.0', -42917.250130081695), ('seats_6.0', -133521.5531644868), ('seats_7.0', -949.8731528255885), ('seats_8.0', -61
# ...

# %%
regpredict = regmodel.predict(X) 
# Predicted selling_price

# %%
regpredict
# Out:
# array([451768.11016412, 509920.43673199, -28921.87543839, ...,
#        245354.14208268, 246777.48965815, 246777.48965815])

# %%
# Residual = Actualselling_price- predictedselling_price
regresid = y-regpredict

# %%
regresid
# Out:
# 0        -1768.110164
# 1      -139920.436732
# 2       186921.875438
# 3       -98460.752163
# 4       -63639.575336
#             ...
# 8123    -17738.222770
# 8124   -169584.477847
# 8125    136645.857917
# 8126     43222.510342
# 8127     43222.510342
# Name: selling_price, Length: 8128, dtype: float64

# %%
# Root Mean Square Error (RMSE) - Diagnostic for all Regression Algorithms
np.sqrt(np.mean(regresid**2)) # RMSE = 306855.84355582553
# Out:
# 306855.84355582553

# %%
print("Skewness",y.skew())
print("Kurtosis",y.kurt())
# Out:
# Skewness 4.193533440675855
# Kurtosis 21.081289012186755

# %%
# Dependent variable - has skewness and Kurtosis - Not closer to normal distribution
# Positive skewness - Logarthimic Transforation or Square Root Transformation
# Negative skewness  - Exponential Transformation or Power transformation

# %%
np.log(y).plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
# Log Linear Model  a regression equation where one or more of the variables are linearized via a log-transformation
regmodel2 = LinearRegression().fit(X,np.log(y))

# %%
regmodel2.score(X,np.log(y))
# Out:
# 0.9096944948105495

# %%
regmodel2_predict = regmodel2.predict(X)

# %%
regmodel2_predict = np.exp(regmodel2_predict)

# %%
regmodel2_resid = y-regmodel2_predict

# %%
np.sqrt(np.mean(regmodel2_resid**2))
# Out:
# 207601.67122530323

# %%
np.round(carsales.selling_price.describe(),2)
# Out:
# count        8128.00
# mean       638271.81
# std        806253.40
# min         29999.00
# 25%        254999.00
# 50%        450000.00
# 75%        675000.00
# max      10000000.00
# Name: selling_price, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(max_depth=8)

# %%
dtr
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
dtr.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
dtr.score(X,y)
# Out:
# 0.9789097975640494

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(dtr,X,y)
# Out:
# array([0.94838725, 0.94030582, 0.96024719, 0.9142266 , 0.88055164])

# %%
np.mean(cross_val_score(dtr,X,y))
# Out:
# 0.928428305454541

# %%
np.mean([0.94838725, 0.94030582, 0.96024719, 0.9142266 , 0.88055164])
# Out:
# 0.9287437000000001

# %%
dtrpredict = dtr.predict(X)

# %%
dtrresid = y-dtrpredict

# %%
np.sqrt(np.mean(dtrresid**2))
# Out:
# 117080.6749935128

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=1000).fit(X,y)

# %%
rfr.score(X,y)
# Out:
# 0.9957303481042674

# %%
pd.DataFrame(X.columns,dtr.feature_importances_).sort_index(ascending=False)
# Out:
#                               0
# 0.743448              max_power
# 0.195086                    Age
# 0.020831                 engine
# 0.014586                mileage
# 0.010573              km_driven
# ...                         ...
# 0.000000  companyname_Chevrolet
# 0.000000     companyname_Daewoo
# 0.000000     companyname_Datsun
# 0.000000       companyname_Fiat
# 0.000000      companyname_Volvo
#
# [61 rows x 1 columns]

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(rfr,X,y)
# Out:
# array([0.9593656 , 0.96750211, 0.97668883, 0.95704607, 0.96392853])

# %%
np.mean([0.9593656 , 0.96750211, 0.97668883, 0.95704607, 0.96392853])
# Out:
# 0.9649062279999999

# %%
rfrpredict = rfr.predict(X)

# %%
rfrresid = y-rfrpredict

# %%
np.sqrt(np.mean(rfrresid**2))
# Out:
# 52679.43126677657

# %%
pd.DataFrame(rfr.feature_importances_,X.columns).sort_values(by=0,ascending=False)
# Out:
#                                    0
# max_power               7.218421e-01
# Age                     1.975292e-01
# km_driven               1.750232e-02
# mileage                 1.302042e-02
# engine                  1.075010e-02
# ...                              ...
# companyname_Ambassador  1.927072e-07
# companyname_Ashok       1.626528e-07
# seats_14.0              7.006614e-08
# companyname_Opel        4.189980e-08
# companyname_Daewoo      2.555476e-08
#
# [61 rows x 1 columns]
